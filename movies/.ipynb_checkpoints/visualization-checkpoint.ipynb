# %%
import pandas as pd
from pathlib import Path

project_path = Path('.')

df = pd.read_csv(project_path / 'data' / 'clean.csv', index_col=0)

df.head()
# Out:
#    belongs_to_collection    budget    imdb_id original_language  \
# 0                      1  14000000  tt2637294                en
# 1                      1  40000000  tt0368933                en
# 2                      0   3300000  tt2582802                en
# 3                      0   1200000  tt1821480                hi
# 4                      0         0  tt1380152                ko
#
#                              original_title  popularity  \
# 0                    Hot Tub Time Machine 2    6.575393
# 1  The Princess Diaries 2: Royal Engagement    8.248895
# 2                                  Whiplash   64.299990
# 3                                   Kahaani    3.174936
# 4                                      마린보이    1.148070
#
#                                 production_companies release_date  runtime  \
# 0  Paramount Pictures,United Artists,Metro-Goldwy...      2/20/15     93.0
# 1                               Walt Disney Pictures       8/6/04    113.0
# ...

# %%
df.budget.count()
df.revenue.count()
# Out:
# 7398
